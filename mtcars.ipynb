# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir("F:\ml-25m\csv")

# %%
x=pd.read_csv("mtcars.csv")
mtcars=pd.DataFrame(x)

# %%
from scipy import stats

# %%
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
z=np.abs(stats.zscore(mtcars['disp']))

# %%
z
# Out:
# array([0.57975032, 0.57975032, 1.00602601, 0.22361542, 1.05977159,
#        0.0469057 , 1.05977159, 0.68877852, 0.73714442, 0.51744848,
#        0.51744848, 0.36953287, 0.36953287, 0.36953287, 1.97790385,
#        1.87953254, 1.71558035, 1.24621597, 1.2708088 , 1.3085178 ,
#        0.90683494, 0.71547199, 0.60070545, 0.97779549, 1.38767597,
#        1.24375669, 0.90519541, 1.11177517, 0.9859931 , 0.70271446,
#        0.57611263, 0.89945709])

# %%
import seaborn as sns

# %%
mtcars.boxplot()

# %%
x=mtcars['hp']
sns.boxplot(x)

# %%
z=np.abs(stats.zscore(mtcars['hp']))

# %%
z
# Out:
# array([0.54365487, 0.54365487, 0.7955699 , 0.54365487, 0.41954967,
#        0.61774753, 1.45684686, 1.25494437, 0.76593284, 0.35101396,
#        0.35101396, 0.49364233, 0.49364233, 0.49364233, 0.86410561,
#        1.01229092, 1.23456889, 1.19567025, 1.40312969, 1.21048878,
#        0.73629578, 0.04908639, 0.04908639, 1.45684686, 0.41954967,
#        1.19567025, 0.82520696, 0.49919927, 1.73839896, 0.41954967,
#        2.79051468, 0.5584734 ])

# %%
threshold=2
print(np.where(z>2))
# Out:
# (array([30], dtype=int32),)

# %%
print(z[30])
# Out:
# 2.790514684425551
